# %%
import pandas as pd

# %%
df=pd.read_csv("Infectious_Disease_cases2001-2014.csv")

# %%
df
# Out:
#             Disease     country  Year     Sex  Count  Population   Rate  \
# 0         Amebiasis  California  2001   Total    571    34514777  1.654
# 1         Amebiasis  California  2001  Female    176    17340743  1.015
# 2         Amebiasis  California  2001    Male    365    17174034  2.125
# 3         Amebiasis  California  2002   Total    442    34940334  1.265
# 4         Amebiasis  California  2002  Female    145    17555714  0.826
# ...             ...         ...   ...     ...    ...         ...    ...
# 141772  Yersiniosis        Yuba  2013  Female      0       36296  0.000
# 141773  Yersiniosis        Yuba  2013    Male      0       36698  0.000
# 141774  Yersiniosis        Yuba  2014   Total      0       73425  0.000
# 141775  Yersiniosis        Yuba  2014  Female      0       36503  0.000
# 141776  Yersiniosis        Yuba  2014    Male      0       36922  0.000
#
#         CI.lower  CI.upper
# 0          1.521     1.796
# 1          0.871     1.176
# ...

# %%
import seaborn as sns
sns.barplot(x='Disease',y='Count',data=df,hue ='Sex',size='Population',palette='tab20b_r')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import seaborn as sns
#       2 sns.barplot(x='Disease',y='Count',data=df,hue ='Sex',size='Population',palette='tab20b_r')
#
# File d:\Anaconda\Lib\site-packages\seaborn\__init__.py:6
#       4 from .palettes import *  # noqa: F401,F403
#       5 from .relational import *  # noqa: F401,F403
# ----> 6 from .regression import *  # noqa: F401,F403
#       7 from .categorical import *  # noqa: F401,F403
#       8 from .distributions import *  # noqa: F401,F403
#
# File d:\Anaconda\Lib\site-packages\seaborn\regression.py:11
#       8 import matplotlib.pyplot as plt
#      10 try:
# ---> 11     import statsmodels
#      12     assert statsmodels
#      13     _has_statsmodels = True
#
# File d:\Anaconda\Lib\site-packages\statsmodels\__init__.py:1
# ...
